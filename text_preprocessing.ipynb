# %%
pip install nltk spacy emoji contractions
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached spacy-3.8.7-cp310-cp310-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached cymem-2.0.11-cp310-cp310-win_amd64.whl.metadata (8.8 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached srsly-2.5.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...

# %%
text = "🚀    Euron    offers        50+ self-paced AI & Data Science courses!     #AI #Learning . ,    "

# %%
import re ,string,nltk,spacy,emoji ,contractions
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,SnowballStemmer
from nltk.tokenize import word_tokenize,sent_tokenize
from spacy.lang.en.stop_words import STOP_WORDS as spacy_stopwords

# %%
text
type(text)
# Out:
# str

# %%
text = text.lower()

# %%
text="🚀    euron    offers        50+ self-paced ai & data science courses!     #ai #learning . ,   let's ,isn't "

# %%
text = contractions.fix(text)

# %%
text
# Out:
# '🚀    euron    offers        50+ self-paced ai & data science courses!     #ai #learning . ,   let us ,is not '

# %%
text = emoji.replace_emoji(text,replace='')

# %%
text
# Out:
# '    euron    offers        50+ self-paced ai & data science courses!     #ai #learning . ,   let us ,is not '

# %%
text = re.sub(r"#\w+","",text)

# %%
text
# Out:
# '    euron    offers        50+ self-paced ai & data science courses!       . ,   let us ,is not '

# %%
text = text.translate(str.maketrans("","",string.punctuation))

# %%
sent_tokenize(text)
# Out:
# ['    euron    offers        50 selfpaced ai  data science courses           let us is not']

# %%
text = '    euron    offers        50 selfpaced ai. Data science courses           let us is not'

# %%
sent_tokenize(text=text)
# Out:
# ['    euron    offers        50 selfpaced ai.',
#  'Data science courses           let us is not']

# %%
word = word_tokenize(text)

# %%
stopwords.words()
# Out:
# ['tyre',
#  'rreth',
#  'le',
#  'atyre',
#  'këta',
#  'megjithëse',
#  'kemi',
#  'per',
#  'ndonëse',
#  'dytë',
#  'pse',
#  'tha',
#  'aty',
#  'ndaj',
#  'ke',
#  'këtë',
#  'duhet',
#  'pa',
#  'perket',
#  'veç',
#  'ndonje',
#  'një',
#  'keshtu',
#  's',
#  'janë',
#  'jane',
#  'ti',
#  'ia',
#  'megjithese',
#  'prej',
#  'ishte',
#  'tjerë',
#  'ai',
#  'se',
#  'tillë',
#  'do',
#  'si',
#  'ja',
#  'tonë',
#  'keta',
#  'pastaj',
#  'ndersa',
#  'siç',
#  'unë',
#  'gjate',
#  'di',
#  'kësaj',
#  'cilin',
#  'kjo',
#  'dhënë',
#  'da',
#  'teper',
#  'ketij',
#  'ama',
#  'pasi',
#  'fjalë',
#  'kanë',
#  'vetem',
#  'za',
#  'd.m.th.',
#  'ose',
#  'pas',
#  'ndonjë',
#  'cila',
#  'ndodhur',
#  'dyte',
#  'ardhur',
#  'kësi',
#  'nga',
#  'vete',
#  'atij',
#  'ta',
#  'jenë',
#  'rendit',
#  'tane',
#  'keso',
#  'deri',
#  'tone',
#  'të',
#  'prandaj',
#  'bëjë',
#  'domethënë',
#  'dhe',
#  'qi',
#  'mirepo',
#  'tona',
#  'që',
#  'u',
#  'këtu',
#  'cilet',
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\scl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words()
# Out:
# ['tyre',
#  'rreth',
#  'le',
#  'atyre',
#  'këta',
#  'megjithëse',
#  'kemi',
#  'per',
#  'ndonëse',
#  'dytë',
#  'pse',
#  'tha',
#  'aty',
#  'ndaj',
#  'ke',
#  'këtë',
#  'duhet',
#  'pa',
#  'perket',
#  'veç',
#  'ndonje',
#  'një',
#  'keshtu',
#  's',
#  'janë',
#  'jane',
#  'ti',
#  'ia',
#  'megjithese',
#  'prej',
#  'ishte',
#  'tjerë',
#  'ai',
#  'se',
#  'tillë',
#  'do',
#  'si',
#  'ja',
#  'tonë',
#  'keta',
#  'pastaj',
#  'ndersa',
#  'siç',
#  'unë',
#  'gjate',
#  'di',
#  'kësaj',
#  'cilin',
#  'kjo',
#  'dhënë',
#  'da',
#  'teper',
#  'ketij',
#  'ama',
#  'pasi',
#  'fjalë',
#  'kanë',
#  'vetem',
#  'za',
#  'd.m.th.',
#  'ose',
#  'pas',
#  'ndonjë',
#  'cila',
#  'ndodhur',
#  'dyte',
#  'ardhur',
#  'kësi',
#  'nga',
#  'vete',
#  'atij',
#  'ta',
#  'jenë',
#  'rendit',
#  'tane',
#  'keso',
#  'deri',
#  'tone',
#  'të',
#  'prandaj',
#  'bëjë',
#  'domethënë',
#  'dhe',
#  'qi',
#  'mirepo',
#  'tona',
#  'që',
#  'u',
#  'këtu',
#  'cilet',
# ...

# %%
'the' in stopwords.words()
# Out:
# True

# %%
len(stopwords.words())
# Out:
# 11009

# %%
word
# Out:
# ['euron',
#  'offers',
#  '50',
#  'selfpaced',
#  'ai',
#  '.',
#  'Data',
#  'science',
#  'courses',
#  'let',
#  'us',
#  'is',
#  'not']

# %%
[w for w in word if w  not in stopwords.words()]
# Out:
# ['euron', 'offers', '50', 'selfpaced', '.', 'Data', 'science', 'courses']

# %%
text
# Out:
# '    euron    offers        50 selfpaced ai. Data science courses           let us is not'

# %%
cleaned = re.sub(r"\s+"," ",text)

# %%
cleaned
# Out:
# ' euron offers 50 selfpaced ai. Data science courses let us is not'

# %%
re.sub(r"\d+","",cleaned)
# Out:
# ' euron offers  selfpaced ai. Data science courses let us is not'

# %%
data = word_tokenize(cleaned)

# %%
data
# Out:
# ['euron',
#  'offers',
#  '50',
#  'selfpaced',
#  'ai',
#  '.',
#  'Data',
#  'science',
#  'courses',
#  'let',
#  'us',
#  'is',
#  'not']

# %%
strmer = PorterStemmer()

# %%
strmer.stem("learning")
# Out:
# 'learn'

# %%
for i in data:
    print(strmer.stem(i))
# Out:
# euron
# offer
# 50
# selfpac
# ai
# .
# data
# scienc
# cours
# let
# us
# is
# not

# %%
snow = SnowballStemmer('english')

# %%
snow.stem("learning")
# Out:
# 'learn'

# %%
for i in data:
    print(snow.stem(i))
# Out:
# euron
# offer
# 50
# selfpac
# ai
# .
# data
# scienc
# cours
# let
# us
# is
# not

# %%
spacy.load("en_core_web_sm")

# %%
# !python -m spacy  download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 12.8/12.8 MB 80.4 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
type(data)
data = nlp(" ".join(data))
# Out:
# spacy.tokens.doc.Doc

# %%
for i in data:
    print(i.lemma_)
# Out:
# euron
# offer
# 50
# selfpace
# ai
# .
# datum
# science
# course
# let
# we
# be
# not
